# %% [markdown]
# 1: 处理数据集，转化成 voc 或者 coco 格式，用于训练和验证
# 2: 模型选择，选择和修改模型配置文件，分类个数等
# 3: 开始训练，设置好模型保存路径
# 4: 对模型进行评估
# 5: 开始预测
# PPYolo 链接：https://yeyupiaoling.blog.csdn.net/article/details/108069066?utm_medium=distribute.pc_relevant.none-task-blog-BlogCommendFromBaidu-1.control&depth_1-utm_source=distribute.pc_relevant.none-task-blog-BlogCommendFromBaidu-1.control
# github： https://github.com/yeyupiaoling/PP-YOLO
#
# paddleDetection: https://github.com/PaddlePaddle/PaddleDetection/blob/release/2.0-beta/docs/tutorials/DetectionPipeline.md

# %% [markdown]
# ### 1: 生成 Annotation xml 文件

# %%
# 安装 lxml 库
# pip3 install lxml

# %%
from lxml.etree import Element, SubElement, tostring
from xml.dom.minidom import parseString
import os
from PIL import Image
# 参考文章：https://blog.csdn.net/w113691/article/details/80393487

workPath = "/home/aistudio/work"
save_xml_path = workPath + "/VOC_Fires/Annotations/"
annotationsDirPath = workPath + "/Fires/train/annotations/"
imagesDirPath = workPath + "/Fires/train/images/"
pasclavocTxt = "/home/aistudio/work/pascla_voc.txt"

# 将所有的 Annotations txt 文件合并成一个文件
def mergeAllAnnotation():
    if os.path.exists(pasclavocTxt) == 0:
        # !touch {pasclavocTxt}
    data = []
    for root, dir, files in os.walk(annotationsDirPath):
        # files 表示该文件夹下的文件list
        for f in files:
            fullname = os.path.join(root, f)
            fileF = open(fullname) 
            for line in fileF.readlines():
                data.append(line)
    f = open(pasclavocTxt, 'w+', encoding='utf-8')
    for i, p in enumerate(data):
        strP = p.replace("非金属打火机", "NonmetallicFire")
        f.write(strP)
    f.close()

# 生成 xml 文件
def make_xml(xmin_tuple, ymin_tuple, xmax_tuple, ymax_tuple, clname, image_name):
 
    node_root = Element('annotation')
 
    node_folder = SubElement(node_root, 'folder')
    node_folder.text = 'VOC'
 
    node_filename = SubElement(node_root, 'filename')
    node_filename.text = image_name
 
    node_object_num = SubElement(node_root, 'object_num')
    node_object_num.text = str(len(xmin_tuple))
 
    node_size = SubElement(node_root, 'size')
    node_width = SubElement(node_size, 'width')
    im = Image.open(imagesDirPath + image_name)
    width, height = im.size
    node_width.text = str(width)
 
    node_height = SubElement(node_size, 'height')
    node_height.text = str(height)
 
    node_depth = SubElement(node_size, 'depth')
    node_depth.text = '3'
    
    for i in range(len(xmin_tuple)):
        node_object = SubElement(node_root, 'object')
        node_name = SubElement(node_object, 'name')
        node_name.text = str(clname[i])
        node_difficult = SubElement(node_object, 'difficult')
        node_difficult.text = '0'
 
        node_bndbox = SubElement(node_object, 'bndbox')
        node_xmin = SubElement(node_bndbox, 'xmin')
        node_xmin.text = str(xmin_tuple[i])
        node_ymin = SubElement(node_bndbox, 'ymin')
        node_ymin.text = str(ymin_tuple[i])
        node_xmax = SubElement(node_bndbox, 'xmax')
        node_xmax.text = str(xmax_tuple[i])
        node_ymax = SubElement(node_bndbox, 'ymax')
        node_ymax.text = str(ymax_tuple[i])
 
 
    xml = tostring(node_root, pretty_print = True)
    dom = parseString(xml)
    return dom

# 将 xml 写入文件
def writeXmlToFile(xmlFileName, dom):
    if os.path.exists(xmlFileName) == 0:
        with open(xmlFileName, 'wb') as f:
            f.write(dom.toprettyxml(indent='\t', encoding='utf-8'))

# 制作所有的 xml 文件
def makeXMLAnnotations():
    if os.path.exists(save_xml_path) == 0:
        os.makedirs(save_xml_path)
    f = open(pasclavocTxt)   
    result = []
    n = 0
    for line in f.readlines():
        result.append(line.split(' '))
        n = n + 1
    img_nameinit = result[0][0]
    xmin = []
    ymin = []
    xmax = []
    ymax = []
    clname = []
    for i in range(0, n):
        if img_nameinit == result[i][0]:
            clname.append(result[i][1])
            xmin.append(result[i][2])
            ymin.append(result[i][3])
            xmax.append(result[i][4])
            ymax.append(result[i][5])
        else:
            dom = make_xml(xmin, ymin, xmax, ymax, clname, img_nameinit)
            por = os.path.splitext(img_nameinit)
            xml_name = os.path.join(save_xml_path, por[0] + '.xml')
            writeXmlToFile(xml_name, dom)
            img_nameinit = result[i][0]
            clname = [result[i][1]]
            xmin = [result[i][2]]
            ymin = [result[i][3]]
            xmax = [result[i][4]]
            ymax = [result[i][5]]
    dom = make_xml(xmin, ymin, xmax, ymax, clname, img_nameinit)
    por = os.path.splitext(img_nameinit)
    xml_name = os.path.join(save_xml_path, por[0] + '.xml')
    writeXmlToFile(xml_name, dom)
    
mergeAllAnnotation()
makeXMLAnnotations()
# !rm {pasclavocTxt}

# %% [markdown]
# ### 生成标准 VOC 文件夹

# %%
VOC_image_path = workPath + "/VOC_Fires/JPEGImages/"
save_xml_path = workPath + "/VOC_Fires/Annotations/"
ImageSetsDirPath = workPath + "/Fires/train/ImageSets/"
trainvalTxt = workPath + "/VOC_Fires/trainval.txt"


# 移动图片到另一个文件夹
def moveImage():
    if os.path.exists(VOC_image_path) == 0:
        os.makedirs(VOC_image_path)
        # !cp -r {imagesDirPath}* {VOC_image_path}

def makeImageSets():
    if os.path.exists(ImageSetsDirPath) == 0:
        os.makedirs(ImageSetsDirPath)


def makeTrainTxt():
    data = []
    # 图片路径 xml路径
    for root, dir, files in os.walk(annotationsDirPath):
        # files 表示该文件夹下的文件list
        for f in files:
            fullname = os.path.join(root, f)
            por = os.path.splitext(fullname)
            prefix = por[0].split('/')[-1]
            line = VOC_image_path+prefix + '.jpg' ' ' + save_xml_path+prefix + '.xml' + '\n'
            data.append(line)
    f = open(trainvalTxt, 'w+', encoding='utf-8')
    for i, p in enumerate(data):
        f.write(p)
    f.close()


moveImage()
makeImageSets()
makeTrainTxt()
# Out:
# 1212

# %% [markdown]
# ### 生成测试文件txt

# %%
testImagesDirPath = workPath + "/Fires/test/images/"
testTxt = workPath + "/VOC_Fires/test.txt"

def makeTestTxt():
    data = []
    # 图片路径 xml路径
    for root, dir, files in os.walk(testImagesDirPath):
        # files 表示该文件夹下的文件list
        for f in files:
            fullname = os.path.join(root, f)
            por = os.path.splitext(fullname)
            prefix = por[0].split('/')[-1]
            line = VOC_image_path+prefix + '.jpg' + '\n'
            data.append(line)
            print(line)
    f = open(testTxt, 'w+', encoding='utf-8')
    for i, p in enumerate(data):
        f.write(p)
    f.close()
    
makeTestTxt()
# Out:
# asa
# gggg
# /home/aistudio/work/VOC_Fires/JPEGImages/000430901018094.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000365201017437.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006728001032683.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001315401027939.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001084801025633.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000201301015798.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001111701025902.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007516101031034.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001167301026458.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000335001017135.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007292501033193.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001238101027166.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006934601034749.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007076401030911.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000351101017296.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007886901029830.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007727901033152.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000294101016726.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001179401026579.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007126601031428.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006703201032435.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001084201025627.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006604301031446.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001142601026211.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007066901030812.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007704801032921.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001225501027040.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001111101025896.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007288301033149.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000853201022317.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000495801018743.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006486001008661.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007768001033553.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000571801019503.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000570001019485.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001275801027543.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007779901033672.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000500501018790.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000348901017274.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007083101030979.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000127501015060.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000214101015926.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007738401033257.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000416901017954.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000255801016343.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007995901030920.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000843201022217.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000127401015059.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006651001031913.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007277301033028.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007082701030975.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000180401015589.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006674201032145.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006516701028128.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000324501017030.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006497801008779.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006700701032410.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006904801034451.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000496701018752.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000275701016542.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007886501029826.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006977301035176.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001222201027007.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001342201028207.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000657301020358.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007195001032153.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000341501017200.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007396701029840.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006619401009995.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007198001032185.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000021401013999.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006493601008737.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007764601033519.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006592101009722.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000617801019963.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006715401010955.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000024501014030.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007197501032180.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001162201026407.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006543701028398.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007177001031964.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007103801031193.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006999301030098.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006556501028526.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006837301033776.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006651101031914.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006650601031909.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007870701029668.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001382601028611.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006988101035284.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007841501029376.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007472401030597.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006847401033877.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007453801030411.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006945401034857.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006696401032367.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001243701027222.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007132201031488.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001177901026564.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001061001025395.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007325601033545.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007461201030485.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007380601034117.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007814601029107.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006860201034005.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007755401033427.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000924801023033.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006602401031427.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000645001020235.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006771601033119.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000113701014922.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006705901032462.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006701001032413.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001243801027223.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006821301033616.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007515901031032.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007728501033158.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006456301027524.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006605501031458.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000028901014074.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007520101031074.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007231501032540.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006970801035111.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000366401017449.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000776201021547.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001111901025904.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000609601019881.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006647401031877.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000815601021941.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000854001022325.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001085201025637.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000336701017152.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000520001018985.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007055901030697.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000409301017878.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006948201034885.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007238101032610.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007988301030844.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000342001017205.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006523601028197.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001373001028515.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006504701028008.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007468901030562.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000843601022221.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007468401030557.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007832201029283.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000844501022230.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007209101032300.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006928501034688.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007782701033700.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006724601011047.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007138601031555.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/008002701030988.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007717201033045.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000537801019163.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000350901017294.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/008013601031097.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007067601030820.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000738301021168.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000722801021013.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000132801015113.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007030201030421.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006836901033772.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007432601030199.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007746001033333.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007159701031781.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006562401009425.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007160401031788.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006535401028315.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000998601023771.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006848801033891.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/007457101030444.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000495701018742.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001235001027135.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/000198401015769.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/001260301027388.jpg
#
# /home/aistudio/work/VOC_Fires/JPEGImages/006946101034864.jpg
